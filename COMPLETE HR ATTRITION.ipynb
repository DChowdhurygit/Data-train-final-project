# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("hr_attrition.tsv",sep="\t")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# Here we have 1470 rows and 35 columns present in df dataset

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# These are the total columns present in our dataset. Here "Attrition" is our target variable and rest of the columns are independent variable

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# We have integer and string type data in our dataset

# %%
df=pd.DataFrame(df)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# All the datas are not numeric so we need to apply Encoding here

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# There is no null value present in df dataset

# %%
df["Attrition"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# Target/dependable variable is binary in nature
#
# Attrition score is between NO and YES
#
# Class imbalance is present as there is 1233 score as NO and 237 score as YES

# %% [markdown]
# # APPLYING ENCODING

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0                23
# 1466   39        0.0             2.0        613         1.0                 6
# 1467   27        0.0             2.0        155         1.0                 4
# 1468   49        0.0             1.0       1023         2.0                 2
# 1469   34        0.0             2.0        628         1.0                 8
#
# ...

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           9.192517     2.912925        2.247619            1.0
# std            8.106864     1.024165        1.331369            0.0
# ...

# %% [markdown]
# Here is the statistical summary of df dataset
#
# Key observation:
#
#  1. The mean higher than the median(50th percentile) in columns 'DistanceFromHome','EmployeeNumber','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion'.'YearsWithCurrManager',skewness might be present in these columns
#  2. we observe difference between the 75th percentile and max in column 'YearsAtCompany',outliers can be present in these columns

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# To check he missing values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# No missing values are present in df dataset

# %% [markdown]
# # To check the correlation

# %%
cor=df.corr()
cor
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeCount                  NaN        NaN             NaN        NaN
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# ...

# %%
plt.figure(figsize=(40,30))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
#
#     Light shades are highly correlated
#     Dark shades are negetively correlated
#
#     'YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager', are highly positively correlated       with each other and negatively correlated with "Attrition"
#     Hence we will check the boxplot first and as according to that we will drop these columns

# %% [markdown]
# # TO CHECK THE DISTRIBUTION OF DATA IN COLUMNS

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
sns.countplot(df["Attrition"])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# Datas are not equally distributed,class imbalanced present

# %% [markdown]
# ### To check the distribution of each column

# %%
sns.distplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# in "Age" datas are equally distributed

# %%
sns.distplot(df["BusinessTravel"])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Density'>

# %% [markdown]
# in "BusinessTravel" skewness is present

# %%
sns.distplot(df["DailyRate"])
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Density'>

# %% [markdown]
# in "DailyRate" datas are equally distributed

# %%
sns.distplot(df["Department"])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Density'>

# %% [markdown]
# in "Department" skewness is present

# %%
sns.distplot(df["DistanceFromHome"])
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Density'>

# %% [markdown]
# in "DistanceFromHome" skewness is present

# %%
sns.distplot(df["EmployeeCount"])
# Out:
# <AxesSubplot:xlabel='EmployeeCount', ylabel='Density'>

# %% [markdown]
# in "EmployeeCount" data is only present in count 1.0

# %%
sns.distplot(df["EmployeeNumber"])
# Out:
# <AxesSubplot:xlabel='EmployeeNumber', ylabel='Density'>

# %% [markdown]
# in "EmployeeNumber" datas are equally distrubuted

# %%
sns.distplot(df["HourlyRate"])
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Density'>

# %% [markdown]
# in "HourlyRate" datas are equally distributed

# %%
sns.distplot(df["JobInvolvement"])
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='Density'>

# %% [markdown]
# in "JobInvolvement" skewness in present

# %% [markdown]
# # TO CHECK THE FREQUENCY OF THE DATA IN THE COLUMNS

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
sns.histplot(df["JobLevel"],bins=20)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='Count'>

# %% [markdown]
# in "JobLevel" data count is between 50 to 500

# %%
sns.histplot(df["JobRole"],bins=20)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='Count'>

# %% [markdown]
# in "JobRole" data count is between 50 to 300

# %%
sns.histplot(df["JobSatisfaction"],bins=20)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Count'>

# %% [markdown]
# in "JobRole" data count is between 450 to 300

# %%
sns.histplot(df["MonthlyIncome"],bins=20)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %% [markdown]
# in "MonthlyIncome" data count is between 350 to 20

# %% [markdown]
# # TO CHECK THE RELATION OF EACH COLUMN TARGET VARIABLE

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
sns.scatterplot(x="Age",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Attrition'>

# %% [markdown]
# The "Äge" has appeared from the count of 20 to 60

# %%
sns.scatterplot(x="BusinessTravel",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Attrition'>

# %% [markdown]
# The "BusinessTravel" has appeared in the count of 0.00,1.00 and 2.00

# %%
sns.scatterplot(x="Department",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Attrition'>

# %% [markdown]
# The "Department" has appeared in the count of 0.00,1.00 and 2.00

# %%
sns.scatterplot(x="DistanceFromHome",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Attrition'>

# %% [markdown]
# The "DistancefromHome" has appeared from the count of 1 to 30

# %%
sns.scatterplot(x="Education",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Attrition'>

# %% [markdown]
# The "Education" has appeared in the count of 1.00,2.00,3.00,4.00 and 5.00

# %%
sns.scatterplot(x="EnvironmentSatisfaction",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='Attrition'>

# %% [markdown]
# The "EnvironmentSatisfaction" has appeared in the count of 1.0,2.0,3.0,4.0

# %%
sns.scatterplot(x="Gender",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Attrition'>

# %% [markdown]
# The "Gender" has appeared in the count of 0.00 and 1.00

# %%
sns.scatterplot(x="JobSatisfaction",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Attrition'>

# %% [markdown]
# The "JobSatisfaction" has appeared in the count of 1.0,2.0,3.0 and 4.0

# %%
sns.scatterplot(x="NumCompaniesWorked",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Attrition'>

# %% [markdown]
# The "NumCompaniesWorked" has appeared in the count of 0 to 9

# %%
sns.scatterplot(x="YearsInCurrentRole",y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='Attrition'>

# %% [markdown]
# The "YearsInCurrentRole" has appeared in the count of 0 to 18

# %% [markdown]
# # PLOTTING OUTLIERS

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
df["Attrition"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present in "Attrition"

# %%
df["Education"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are not present in "Education"

# %%
df["PerformanceRating"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present in "PerformanceRating"

# %%
df["TrainingTimesLastYear"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present in "TrainingTimesLastYear"

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %% [markdown]
# To check all the columns together we need to apply below code here

# %%
df.plot(kind="box",subplots=True,layout=(5,7),figsize=(20,20))
# Out:
# Age                            AxesSubplot(0.125,0.749828;0.0945122x0.130172)
# Attrition                   AxesSubplot(0.238415,0.749828;0.0945122x0.130172)
# BusinessTravel              AxesSubplot(0.351829,0.749828;0.0945122x0.130172)
# DailyRate                   AxesSubplot(0.465244,0.749828;0.0945122x0.130172)
# Department                  AxesSubplot(0.578659,0.749828;0.0945122x0.130172)
# DistanceFromHome            AxesSubplot(0.692073,0.749828;0.0945122x0.130172)
# Education                   AxesSubplot(0.805488,0.749828;0.0945122x0.130172)
# EducationField                 AxesSubplot(0.125,0.593621;0.0945122x0.130172)
# EmployeeCount               AxesSubplot(0.238415,0.593621;0.0945122x0.130172)
# EmployeeNumber              AxesSubplot(0.351829,0.593621;0.0945122x0.130172)
# EnvironmentSatisfaction     AxesSubplot(0.465244,0.593621;0.0945122x0.130172)
# Gender                      AxesSubplot(0.578659,0.593621;0.0945122x0.130172)
# ...

# %% [markdown]
# we have outliers present in "Attrition","MonthlyIncome","NumCompaniesWorked","PerformanceRating","StockOptionLevel","TotalWorkingYears","TrainingTimesLastY ear","YearsAtCompany",'YearsInCurrentRole', 'YearsSinceLastPromotion','YearsWithCurrManager'

# %% [markdown]
# Observation:
#
#
# As depending on the correlation with our target variable"Attrition" and the outliers present in the dataset we need to drop "TotalWorkingYears","YearsAtCompany" and we have null values present in column "EmployeeCount","Over18","StandardHours",hence we are dropping theses columns aswell

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.drop(['EmployeeCount','Over18','StandardHours','TotalWorkingYears','YearsAtCompany'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1470, 30)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# Dropped columns are no longer present in the dataset

# %% [markdown]
# # REMOVING OUTLIERS

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.4463504 , 2.28090588, 0.59004834, ..., 0.0632959 , 0.67914568,
#         0.24583399],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.76499762, 0.36871529,
#         0.80654148],
#        [0.008343  , 2.28090588, 0.59004834, ..., 1.16768726, 0.67914568,
#         1.15593471],
#        ...,
#        [1.08667552, 0.4384223 , 0.59004834, ..., 0.61549158, 0.67914568,
#         0.31487349],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.48889978, 0.67914568,
#         1.08689522],
#        [0.32016256, 0.4384223 , 0.59004834, ..., 0.33939374, 0.36871529,
#         0.59522723]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  28,   45,   62,   63,   64,  110,  123,  123,  123,  126,  153,
#         178,  187,  190,  218,  231,  231,  237,  281,  326,  386,  386,
#         425,  427,  466,  535,  561,  584,  595,  616,  635,  653,  686,
#         701,  716,  746,  752,  799,  838,  861,  875,  875,  914,  922,
#         926,  926,  937,  976,  976, 1008, 1024, 1078, 1078, 1086, 1093,
#        1138, 1156, 1221, 1223, 1242, 1295, 1301, 1303, 1327, 1331, 1348,
#        1351, 1414, 1430], dtype=int64), array([29, 28, 28, 27, 28, 28, 27, 28, 29, 28, 29, 28, 29, 27, 28, 27, 29,
#        28, 27, 28, 28, 29, 28, 28, 27, 28, 29, 28, 28, 29, 29, 28, 29, 28,
#        27, 27, 28, 28, 28, 28, 28, 29, 28, 28, 28, 29, 28, 27, 28, 28, 27,
#        28, 29, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 27, 28, 29, 27, 28,
#        27], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0                23
# 1466   39        0.0             2.0        613         1.0                 6
# 1467   27        0.0             2.0        155         1.0                 4
# 1468   49        0.0             1.0       1023         2.0                 2
# 1469   34        0.0             2.0        628         1.0                 8
#
# ...

# %%
df_new.shape
# Out:
# (1409, 30)

# %%
df.shape
# Out:
# (1470, 30)

# %%
(61/1470)
# Out:
# 0.04149659863945578

# %% [markdown]
# We have lost 0.04% data so far by removing outliers

# %% [markdown]
# # DIVIDING THE COLUMNS AS x AND y

# %%
x=df.drop("Attrition",axis=1)
y=df["Attrition"]

# %%
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41             2.0       1102         2.0                 1          2
# 1      49             1.0        279         1.0                 8          1
# 2      37             2.0       1373         1.0                 2          2
# 3      33             1.0       1392         1.0                 3          4
# 4      27             2.0        591         1.0                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36             1.0        884         1.0                23          2
# 1466   39             2.0        613         1.0                 6          1
# 1467   27             2.0        155         1.0                 4          3
# 1468   49             1.0       1023         2.0                 2          3
# 1469   34             2.0        628         1.0                 8          3
#
# ...

# %% [markdown]
# # REMOVING THE SKEWNESS

# %%
df.skew()
# Out:
# Age                         0.462988
# Attrition                   1.817331
# BusinessTravel             -1.441060
# DailyRate                  -0.006463
# Department                  0.160614
# DistanceFromHome            0.956788
# Education                  -0.280847
# EducationField              0.546519
# EmployeeNumber              0.018394
# EnvironmentSatisfaction    -0.328873
# Gender                     -0.416548
# HourlyRate                 -0.033354
# JobInvolvement             -0.501805
# JobLevel                    1.106495
# JobRole                    -0.374605
# JobSatisfaction            -0.338978
# MaritalStatus              -0.162370
# MonthlyIncome               1.498726
# MonthlyRate                 0.019828
# NumCompaniesWorked          1.033977
# OverTime                    0.951898
# PercentSalaryHike           0.804290
# PerformanceRating           1.926683
# RelationshipSatisfaction   -0.294650
# StockOptionLevel            0.967729
# ...

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method="yeo-johnson")

# %%
x
# Out:
# array([[ 5.74960343e-01,  6.35203754e-01,  7.57720729e-01, ...,
#          2.70885790e-01, -1.07630342e+00,  5.60762964e-01],
#        [ 1.32429455e+00, -1.39502104e+00, -1.33906125e+00, ...,
#          9.85623188e-01,  1.81106258e-01,  9.96699857e-01],
#        [ 1.53958386e-01,  6.35203754e-01,  1.34136316e+00, ...,
#         -1.57558065e+00, -1.07630342e+00, -1.53239454e+00],
#        ...,
#        [-1.09067119e+00,  6.35203754e-01, -1.75477712e+00, ...,
#         -4.06890961e-01, -1.07630342e+00, -1.11367940e-03],
#        [ 1.32429455e+00, -1.39502104e+00,  5.81006194e-01, ...,
#          7.72964833e-01, -1.07630342e+00,  1.18475196e+00],
#        [-1.87081727e-01,  6.35203754e-01, -3.63494450e-01, ...,
#         -3.70723016e-02,  1.81106258e-01, -3.65514548e-01]])

# %% [markdown]
# Using power_transform method to remove the skewnesss

# %% [markdown]
# # APPLYING SMOTE TECHNIQUE FOR IMBALANCED DATA

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0'

# %%
import numpy
numpy.__version__
# Out:
# '1.19.2'

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()

# %%
train_x,train_y=smt.fit_resample(x,y)

# %%
train_y.value_counts()
# Out:
# 0.0    1178
# 1.0    1178
# Name: Attrition, dtype: int64

# %%
sns.countplot(train_y)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# By using smote technique we make the data balanced

# %% [markdown]
# # APPLYING SCALING

# %%
from sklearn.preprocessing import StandardScaler 
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 5.74960343e-01,  6.35203754e-01,  7.57720729e-01, ...,
#          2.70885790e-01, -1.07630342e+00,  5.60762964e-01],
#        [ 1.32429455e+00, -1.39502104e+00, -1.33906125e+00, ...,
#          9.85623188e-01,  1.81106258e-01,  9.96699857e-01],
#        [ 1.53958386e-01,  6.35203754e-01,  1.34136316e+00, ...,
#         -1.57558065e+00, -1.07630342e+00, -1.53239454e+00],
#        ...,
#        [-1.09067119e+00,  6.35203754e-01, -1.75477712e+00, ...,
#         -4.06890961e-01, -1.07630342e+00, -1.11367940e-03],
#        [ 1.32429455e+00, -1.39502104e+00,  5.81006194e-01, ...,
#          7.72964833e-01, -1.07630342e+00,  1.18475196e+00],
#        [-1.87081727e-01,  6.35203754e-01, -3.63494450e-01, ...,
#         -3.70723016e-02,  1.81106258e-01, -3.65514548e-01]])

# %%
x
# Out:
# array([[ 5.74960343e-01,  6.35203754e-01,  7.57720729e-01, ...,
#          2.70885790e-01, -1.07630342e+00,  5.60762964e-01],
#        [ 1.32429455e+00, -1.39502104e+00, -1.33906125e+00, ...,
#          9.85623188e-01,  1.81106258e-01,  9.96699857e-01],
#        [ 1.53958386e-01,  6.35203754e-01,  1.34136316e+00, ...,
#         -1.57558065e+00, -1.07630342e+00, -1.53239454e+00],
#        ...,
#        [-1.09067119e+00,  6.35203754e-01, -1.75477712e+00, ...,
#         -4.06890961e-01, -1.07630342e+00, -1.11367940e-03],
#        [ 1.32429455e+00, -1.39502104e+00,  5.81006194e-01, ...,
#          7.72964833e-01, -1.07630342e+00,  1.18475196e+00],
#        [-1.87081727e-01,  6.35203754e-01, -3.63494450e-01, ...,
#         -3.70723016e-02,  1.81106258e-01, -3.65514548e-01]])

# %% [markdown]
# applying scaling technique to make all the data even

# %% [markdown]
# # APPLYING VARIOUS MODEL TO GET THE BEST ACCURACY SCORE

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# # SPLITTING THE DATAFRAME

# %%
for i in range(0,1000):
    train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(train_x,train_y)
    pred_train=lr.predict(train_x)
    pred_test=lr.predict(test_x)
    if round(accuracy_score(train_y,pred_train)*100,1)==round(accuracy_score(test_y,pred_test)*100,1):
        print("At random state",i,"The model performs well")
        print("At random state:-",i)
        print("Trainning r2 score is:-",accuracy_score(train_y,pred_train)*100)
        print("Testing r2 score is:-",accuracy_score(test_y,pred_test)*100)
# Out:
# At random state 41 The model performs well
# At random state:- 41
# Trainning r2 score is:- 88.28748890860693
# Testing r2 score is:- 88.29787234042553
# At random state 60 The model performs well
# At random state:- 60
# Trainning r2 score is:- 87.93256433007986
# Testing r2 score is:- 87.94326241134752
# At random state 89 The model performs well
# At random state:- 89
# Trainning r2 score is:- 87.93256433007986
# Testing r2 score is:- 87.94326241134752
# At random state 198 The model performs well
# At random state:- 198
# Trainning r2 score is:- 87.22271517302573
# Testing r2 score is:- 87.2340425531915
# At random state 217 The model performs well
# At random state:- 217
# Trainning r2 score is:- 87.5776397515528
# Testing r2 score is:- 87.58865248226951
# At random state 221 The model performs well
# At random state:- 221
# Trainning r2 score is:- 87.93256433007986
# Testing r2 score is:- 87.94326241134752
# At random state 400 The model performs well
# At random state:- 400
# ...

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20,random_state=41)

# %%
from sklearn.metrics import classification_report
print(classification_report(test_y,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.94      0.88       235
#          1.0       0.18      0.06      0.09        47
#
#     accuracy                           0.79       282
#    macro avg       0.51      0.50      0.49       282
# weighted avg       0.72      0.79      0.75       282

# %% [markdown]
# By applying LogisticRegression we are getting the accuracy of 0.88

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(train_x,train_y)
pred=dtc.predict(test_x)
acc=classification_report(test_y,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.84      0.84       343
#          1.0       0.33      0.35      0.34        80
#
#     accuracy                           0.74       423
#    macro avg       0.59      0.59      0.59       423
# weighted avg       0.75      0.74      0.75       423

# %% [markdown]
# By applying DecisionTreeClassifier we are getting the accuracy of 0.74

# %% [markdown]
# ### RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc.fit(train_x,train_y)
pred=rfc.predict(test_x)
acc=classification_report(test_y,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      1.00      0.91       343
#          1.0       0.93      0.17      0.29        80
#
#     accuracy                           0.84       423
#    macro avg       0.89      0.59      0.60       423
# weighted avg       0.86      0.84      0.79       423

# %% [markdown]
# We are getting the accuracy of 0.84 by using RandomForestClassifier

# %% [markdown]
# ### SupportVectorClassifier

# %%
svc=SVC()
svc.fit(train_x,train_y)
pred=svc.predict(test_x)
acc=classification_report(test_y,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.99      0.92       343
#          1.0       0.91      0.26      0.41        80
#
#     accuracy                           0.86       423
#    macro avg       0.88      0.63      0.66       423
# weighted avg       0.86      0.86      0.82       423

# %% [markdown]
# We are getting the accuracy of 0.86 by using SupportVectorClassifier

# %% [markdown]
# ### KNeighborsClassifier

# %%
knn=KNeighborsClassifier()
knn.fit(train_x,train_y)
pred=knn.predict(test_x)
acc=classification_report(test_y,pred)
print(acc)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.99      0.90       343
#          1.0       0.69      0.14      0.23        80
#
#     accuracy                           0.83       423
#    macro avg       0.76      0.56      0.57       423
# weighted avg       0.80      0.83      0.77       423

# %% [markdown]
# We are getting the accuracy of 0.83 by using KNeighborsClassifier

# %% [markdown]
# # CHECKING THE CROSS VALIDATION SCORE WITH ACCURACY SCORE

# %% [markdown]
# ### Checking the cross validation score of LogisticRegression

# %%
pred_lr=lr.predict(test_x)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(test_y,pred_lr)
for j in range(2,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("Accuracy score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 86.51454706640878
# Accuracy score is:- 86.28841607565012
#
#
# At cv:- 3
# Cross validation score is:- 86.58652028610746
# Accuracy score is:- 86.28841607565012
#
#
# At cv:- 4
# Cross validation score is:- 86.30166752510945
# Accuracy score is:- 86.28841607565012
#
#
# At cv:- 5
# Cross validation score is:- 86.72925973599858
# Accuracy score is:- 86.28841607565012
#
#
# At cv:- 6
# Cross validation score is:- 86.80032733224223
# Accuracy score is:- 86.28841607565012
#
#
# At cv:- 7
# Cross validation score is:- 87.08367638469603
# Accuracy score is:- 86.28841607565012
#
#
# At cv:- 8
# Cross validation score is:- 87.15251027221368
# Accuracy score is:- 86.28841607565012
#
#
# At cv:- 9
# Cross validation score is:- 86.87054276226252
# Accuracy score is:- 86.28841607565012

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=7).mean()
print("The cv score is:-",lsscore_selected,"\nThe accuracy_score is:-",lss)
# Out:
# The cv score is:- 0.8708367638469604
# The accuracy_score is:- 0.8628841607565012

# %% [markdown]
# ### Checking the cross validation score of DecisionTreeClassifier

# %%
pred_dtc=dtc.predict(test_x)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(test_y,pred_dtc)
for j in range(2,10):
    lsscore=cross_val_score(dtc,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("Accuracy score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 77.00586315280464
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 3
# Cross validation score is:- 75.79533941236069
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 4
# Cross validation score is:- 78.06886588977594
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 5
# Cross validation score is:- 78.63784356780495
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 6
# Cross validation score is:- 77.43074498393648
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 7
# Cross validation score is:- 72.55061327028226
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 8
# Cross validation score is:- 76.08540382639958
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 9
# Cross validation score is:- 73.94387282922315
# Accuracy score is:- 74.46808510638297

# %%
lsscore_selected=cross_val_score(dtc,x,y,cv=3).mean()
print("The cv score is:-",lsscore_selected,"\nThe accuracy_score is:-",lss)
# Out:
# The cv score is:- 0.7586520286107455
# The accuracy_score is:- 0.8250591016548463

# %% [markdown]
# # Checking the cross validation score of RandomForestClassifier

# %%
pred_rfc=rfc.predict(test_x)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(test_y,pred_dtc)
for j in range(2,10):
    lsscore=cross_val_score(rfc,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("Accuracy score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 85.30847034171502
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 3
# Cross validation score is:- 85.66408081174673
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 4
# Cross validation score is:- 85.09629313674995
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 5
# Cross validation score is:- 85.23787890260216
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 6
# Cross validation score is:- 84.9539310177608
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 7
# Cross validation score is:- 85.23753228201284
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 8
# Cross validation score is:- 85.37934964047251
# Accuracy score is:- 74.46808510638297
#
#
# At cv:- 9
# Cross validation score is:- 84.73968824287294
# Accuracy score is:- 74.46808510638297

# %%
lsscore_selected=cross_val_score(rfc,x,y,cv=9).mean()
print("The cv score is:-",lsscore_selected,"\nThe accuracy_score is:-",lss)
# Out:
# The cv score is:- 0.8516749233309743
# The accuracy_score is:- 0.8250591016548463

# %% [markdown]
# ### Checking the cross validation score of SupportVectorClassifier

# %%
pred_svc=svc.predict(test_x)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(test_y,pred_svc)
for j in range(2,10):
    lsscore=cross_val_score(svc,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("Accuracy score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 85.73480818826565
# Accuracy score is:- 85.57919621749409
#
#
# At cv:- 3
# Cross validation score is:- 86.37330066990278
# Accuracy score is:- 85.57919621749409
#
#
# At cv:- 4
# Cross validation score is:- 85.94735867885656
# Accuracy score is:- 85.57919621749409
#
#
# At cv:- 5
# Cross validation score is:- 86.37389263269478
# Accuracy score is:- 85.57919621749409
#
#
# At cv:- 6
# Cross validation score is:- 86.44480814693581
# Accuracy score is:- 85.57919621749409
#
#
# At cv:- 7
# Cross validation score is:- 86.79867986798679
# Accuracy score is:- 85.57919621749409
#
#
# At cv:- 8
# Cross validation score is:- 86.30063880328711
# Accuracy score is:- 85.57919621749409
#
#
# At cv:- 9
# Cross validation score is:- 86.58428148874009
# Accuracy score is:- 85.57919621749409

# %%
lsscore_selected=cross_val_score(svc,x,y,cv=9).mean()
print("The cv score is:-",lsscore_selected,"\nThe accuracy_score is:-",lss)
# Out:
# The cv score is:- 0.8658428148874009
# The accuracy_score is:- 0.8250591016548463

# %% [markdown]
# ### Checking the cross validation score of KNeighborsClassifier

# %%
pred_knn=knn.predict(test_x)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(test_y,pred_knn)
for j in range(2,10):
    lsscore=cross_val_score(knn,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("Accuracy score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 84.1020913926499
# Accuracy score is:- 82.50591016548464
#
#
# At cv:- 3
# Cross validation score is:- 84.38612409079225
# Accuracy score is:- 82.50591016548464
#
#
# At cv:- 4
# Cross validation score is:- 84.81179983260365
# Accuracy score is:- 82.50591016548464
#
#
# At cv:- 5
# Cross validation score is:- 84.52790187022033
# Accuracy score is:- 82.50591016548464
#
#
# At cv:- 6
# Cross validation score is:- 84.81178396072013
# Accuracy score is:- 82.50591016548464
#
#
# At cv:- 7
# Cross validation score is:- 84.95359130795809
# Accuracy score is:- 82.50591016548464
#
#
# At cv:- 8
# Cross validation score is:- 84.88339432460195
# Accuracy score is:- 82.50591016548464
#
#
# At cv:- 9
# Cross validation score is:- 84.88576768831545
# Accuracy score is:- 82.50591016548464

# %%
lsscore_selected=cross_val_score(knn,x,y,cv=2).mean()
print("The cv score is:-",lsscore_selected,"\nThe accuracy_score is:-",lss)
# Out:
# The cv score is:- 0.841020913926499
# The accuracy_score is:- 0.8250591016548463

# %% [markdown]
# As we can see by using LogisticRegression we are getting the best accuracy_score

# %% [markdown]
# # AUC ROC CURVE

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=lr.predict_proba(test_x)[:,1]
y_pred_prob
# Out:
# array([7.01226571e-02, 8.46211376e-01, 6.33075044e-02, 7.63976473e-03,
#        2.16094111e-02, 9.34591595e-03, 6.21829161e-02, 1.71017920e-01,
#        1.02867927e-02, 2.42874691e-01, 3.26349296e-01, 6.77593071e-02,
#        2.77467342e-03, 2.51808778e-01, 7.19346924e-01, 1.59509775e-01,
#        1.12888128e-02, 7.09366912e-02, 1.50928663e-01, 2.03066164e-01,
#        7.20248196e-01, 7.36471992e-02, 6.81104379e-02, 7.01001149e-03,
#        7.24074675e-02, 4.33241738e-01, 9.96860936e-02, 3.31221807e-02,
#        3.28770478e-02, 9.70628317e-02, 1.29896740e-01, 1.79402572e-02,
#        1.01235682e-01, 3.97105527e-02, 1.05145528e-02, 1.88571352e-01,
#        8.76589252e-02, 6.80204863e-01, 1.74308047e-01, 1.78050917e-02,
#        4.43735480e-02, 1.89256372e-01, 3.42698486e-03, 2.22496557e-02,
#        6.34161404e-02, 5.62737335e-01, 5.54401426e-02, 2.01514775e-02,
#        7.95307942e-02, 3.85208866e-02, 2.31944318e-01, 5.55084031e-01,
# ...

# %%
fpr,tpr,threshold=roc_curve(test_y,y_pred_prob)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.00291545, 0.00291545,
#        0.0058309 , 0.0058309 , 0.00874636, 0.00874636, 0.01166181,
#        0.01166181, 0.01457726, 0.01457726, 0.02040816, 0.02040816,
#        0.02332362, 0.02332362, 0.02623907, 0.02623907, 0.02915452,
#        0.02915452, 0.03206997, 0.03206997, 0.03498542, 0.03498542,
#        0.03790087, 0.03790087, 0.04956268, 0.04956268, 0.06122449,
#        0.06122449, 0.0728863 , 0.0728863 , 0.0787172 , 0.0787172 ,
#        0.09329446, 0.09329446, 0.09620991, 0.09620991, 0.11078717,
#        0.11078717, 0.12244898, 0.12244898, 0.13411079, 0.13411079,
#        0.13994169, 0.13994169, 0.14577259, 0.14577259, 0.15451895,
#        0.15451895, 0.17784257, 0.17784257, 0.20408163, 0.20408163,
#        0.2244898 , 0.2244898 , 0.23906706, 0.23906706, 0.24489796,
#        0.24489796, 0.31195335, 0.31195335, 0.37900875, 0.37900875,
#        0.41690962, 0.41690962, 0.43731778, 0.43731778, 0.4664723 ,
# ...

# %%
tpr
# Out:
# array([0.    , 0.0125, 0.1625, 0.1625, 0.1875, 0.1875, 0.2125, 0.2125,
#        0.2875, 0.2875, 0.3125, 0.3125, 0.3375, 0.3375, 0.3625, 0.3625,
#        0.3875, 0.3875, 0.4   , 0.4   , 0.4125, 0.4125, 0.425 , 0.425 ,
#        0.45  , 0.45  , 0.4875, 0.4875, 0.5   , 0.5   , 0.525 , 0.525 ,
#        0.5375, 0.5375, 0.55  , 0.55  , 0.575 , 0.575 , 0.6125, 0.6125,
#        0.625 , 0.625 , 0.65  , 0.65  , 0.675 , 0.675 , 0.6875, 0.6875,
#        0.7   , 0.7   , 0.7125, 0.7125, 0.725 , 0.725 , 0.7375, 0.7375,
#        0.7625, 0.7625, 0.775 , 0.775 , 0.7875, 0.7875, 0.8   , 0.8   ,
#        0.8125, 0.8125, 0.825 , 0.825 , 0.85  , 0.85  , 0.8625, 0.8625,
#        0.8875, 0.8875, 0.9125, 0.9125, 0.925 , 0.925 , 0.9375, 0.9375,
#        0.95  , 0.95  , 0.9625, 0.9625, 0.975 , 0.975 , 0.9875, 0.9875,
#        1.    , 1.    ])

# %%
threshold
# Out:
# array([1.93444409e+00, 9.34444088e-01, 7.81532784e-01, 7.54767320e-01,
#        7.32466298e-01, 7.25828321e-01, 7.20248196e-01, 7.19346924e-01,
#        6.40448591e-01, 6.29917688e-01, 5.84454334e-01, 5.73895661e-01,
#        5.65683407e-01, 5.62737335e-01, 5.55084031e-01, 5.48376513e-01,
#        5.37941195e-01, 5.11983668e-01, 5.06573816e-01, 5.05240128e-01,
#        4.96209045e-01, 4.95843952e-01, 4.83874654e-01, 4.80166493e-01,
#        4.73244989e-01, 4.56088223e-01, 4.49672094e-01, 4.33241738e-01,
#        4.24158961e-01, 4.12948812e-01, 3.96241538e-01, 3.65590891e-01,
#        3.60481254e-01, 3.51081079e-01, 3.50519260e-01, 3.17976209e-01,
#        3.14267997e-01, 3.14238623e-01, 3.12302027e-01, 2.93208600e-01,
#        2.92854078e-01, 2.86631300e-01, 2.86002709e-01, 2.79122870e-01,
#        2.64162419e-01, 2.59682677e-01, 2.57972112e-01, 2.49109400e-01,
#        2.46993919e-01, 2.42874691e-01, 2.42357405e-01, 2.21964838e-01,
# ...

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label="LogisticRegression ")
plt.xlabel("FALSE POSITIVE RATE")
plt.ylabel("TRUE POSITIVE RATE")
plt.title("LogisticRegression")
plt.show()

# %% [markdown]
# # SAVING THE BEST MODEL

# %%
import joblib
joblib.dump(lr,"best_lrfile1.obj")
# Out:
# ['best_lrfile1.obj']
