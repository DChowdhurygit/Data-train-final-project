# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Here we have 30 rows and 17 columns present in df dataset

# %%
df=pd.DataFrame(df)
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# All the datas are numeric so we dont need to apply LabelEncoder here

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# These are the total columns present in our dataset. Here "W" is our target variable and rest of the columns are independent variable

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no null value present in df dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Here is the statistical summary of df dataset
#
# Key observation:
#
#  1. The mean higher than the median(50th percentile) in columns 'H','HR','CG','SV','E',skewness might be present in these           columns
#  2. we dont observe much difference between the 75th percentile and max,extreme outliers can not be present in the dataset

# %%
df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# Target/dependable variable is discrete and categorical in nature
#
# W score starts from 63 to 100
# where 63 is the low score and 100 is the best
#
# only scores obtained are between 63 to 100

# %%
df.W.value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %% [markdown]
# Observation:
#
#     W has most values concerntrated in the categories of 68,81,74,76,83
#     Few observations present in the rest of the categories

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# To check he missing values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# No missing values are present in df dataset

# %% [markdown]
# # To check the correlation

# %%
cor=df.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
#
#     Light shades are highly correlated
#     "W" is highly correlated with "SV"
#
#     "RA","ER","ERA" are highly positively correlated with each other and negatively correlated with "W"
#     Hence we will drop these columns as we are going to use Linear Regression here

# %% [markdown]
# # TO CHECK THE DISTRIBUTION OF DATA IN COLUMNS

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
sns.distplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "W" column,skewness is not present

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %% [markdown]
# Slight skewness is visible in 'R'column

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "AB" column,skewness is not present

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %% [markdown]
# Slight skewness is visible in 'H'column

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "2B" column,skewness is not present

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "3B" column,skewness is not present

# %%
sns.distplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %% [markdown]
# Slight skewness is visible in 'HR'column

# %%
sns.distplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "SB" column,skewness is not present

# %%
sns.distplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "RA" column,skewness is not present

# %%
sns.distplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "ER" column,skewness is not present

# %%
sns.distplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "ERA" column,skewness is not present

# %%
sns.distplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %% [markdown]
# Slight skewness is visible in 'CG' column

# %%
sns.distplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "SHO" column,skewness is not present

# %%
sns.distplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %% [markdown]
# Datas are equally distributed in the "SV" column,skewness is not present

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# Slight skewness is visible in 'E' column

# %% [markdown]
# ### BI-VARIATE ANALYSIS

# %%
df.plot(kind="kde",subplots=True,layout=(3,6),figsize=(15,15))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %% [markdown]
# We can check the distribution of the whole dataset by applying above code

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # PLOTTING OUTLIERS

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
df["W"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are not present in "W" column

# %%
df["R"].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in "R" column

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %% [markdown]
# If we want to see the boxplot of the whole dataset we need to apply below code

# %%
df.plot(kind="box",subplots=True,layout=(2,9),figsize=(20,15))
# Out:
# W         AxesSubplot(0.125,0.536818;0.0731132x0.343182)
# R      AxesSubplot(0.212736,0.536818;0.0731132x0.343182)
# AB     AxesSubplot(0.300472,0.536818;0.0731132x0.343182)
# H      AxesSubplot(0.388208,0.536818;0.0731132x0.343182)
# 2B     AxesSubplot(0.475943,0.536818;0.0731132x0.343182)
# 3B     AxesSubplot(0.563679,0.536818;0.0731132x0.343182)
# HR     AxesSubplot(0.651415,0.536818;0.0731132x0.343182)
# BB     AxesSubplot(0.739151,0.536818;0.0731132x0.343182)
# SO     AxesSubplot(0.826887,0.536818;0.0731132x0.343182)
# SB           AxesSubplot(0.125,0.125;0.0731132x0.343182)
# RA        AxesSubplot(0.212736,0.125;0.0731132x0.343182)
# ER        AxesSubplot(0.300472,0.125;0.0731132x0.343182)
# ERA       AxesSubplot(0.388208,0.125;0.0731132x0.343182)
# CG        AxesSubplot(0.475943,0.125;0.0731132x0.343182)
# SHO       AxesSubplot(0.563679,0.125;0.0731132x0.343182)
# SV        AxesSubplot(0.651415,0.125;0.0731132x0.343182)
# ...

# %% [markdown]
# Observation:
#
# We have outliers present in the columns 'R','ERA','SHO','SV','E'

# %% [markdown]
# # TO CHECK THE FREQUENCY OF THE DATA IN THE COLUMNS

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
sns.histplot(df["W"],bins=20)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %% [markdown]
# In "W" column most of our data is present in the count of 1.0,and very few has appeared in count of 4.0

# %%
sns.histplot(df["R"],bins=20)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %% [markdown]
# In "R" column most of our data is present in the count of 1.0,and very few has appeared in count of 6.0

# %%
sns.histplot(df["AB"],bins=20)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Count'>

# %% [markdown]
# In "AB" column most of our data is present in the count of 1.0,and very few has appeared in count of 4.0

# %%
sns.histplot(df["H"],bins=20)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Count'>

# %% [markdown]
# In "H" column most of our data is present in the count of 1.0 to 3.0,and very few has appeared in count of 4.0

# %%
sns.histplot(df["2B"],bins=20)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Count'>

# %% [markdown]
# In "2B" column most of our data is present in the count of 1.0,and very few has appeared in count of 2.0 to 4.0

# %%
sns.histplot(df["3B"],bins=20)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Count'>

# %% [markdown]
# In "3B" column most of our data is present in the count of 1.0,and very few has appeared in count of 2.0 to 5.0

# %%
sns.histplot(df["HR"],bins=20)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Count'>

# %% [markdown]
# In "HR" column most of our data is present in the count of 1.0 to 2.0,and very few has appeared in count of 4.0

# %%
sns.histplot(df["BB"],bins=20)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Count'>

# %% [markdown]
# In "BB" column most of our data is present in the count of 1.0 to 2.0,and few of them has appeared in count of 3.0

# %%
sns.histplot(df["SO"],bins=20)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Count'>

# %% [markdown]
# In "SO" column most of our data is present in the count of 1.0 to 4.0,and very few has appeared in count of 6.0

# %%
sns.histplot(df["SB"],bins=20)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Count'>

# %% [markdown]
# In "SB" column most of our data is present in the count of 1.0 and 2.0,and very few has appeared in count of 3.0 to 4.0

# %%
sns.histplot(df["RA"],bins=20)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Count'>

# %% [markdown]
# In "RA" column most of our data is present in the count of 2.0,and very few has appeared in count of 3.0

# %%
sns.histplot(df["ER"],bins=20)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Count'>

# %% [markdown]
# In "ER" column most of our data is present in the count of 1.0 and 3.0,and very few has appeared in count of 4.0

# %%
sns.histplot(df["ERA"],bins=20)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Count'>

# %% [markdown]
# In "ERA" column most of our data is present in the count of 1.0 to 2.0,and very few has appeared in count of 6.0

# %%
sns.histplot(df["CG"],bins=20)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Count'>

# %% [markdown]
# In "CG" column most of our data is present in the count of 3,and very few has appeared in count of 4 to 7

# %%
sns.histplot(df["SHO"],bins=20)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Count'>

# %% [markdown]
# In "SHO" column most of our data is present in the count of 2,and very few has appeared in count of 3 to 7

# %%
sns.histplot(df["SV"],bins=20)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Count'>

# %% [markdown]
# In "SV" column most of our data is present in the count of 1,and very few has appeared in count of 5

# %%
sns.histplot(df["E"],bins=20)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Count'>

# %% [markdown]
# In "E" column most of our data is present in the count of 1 to 3,and very few has appeared in count of 6

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %% [markdown]
# To check the relation between two variable we can use scatter plot

# %%
plt.scatter(df["R"],df["W"])

# %% [markdown]
# We can check the data spread of column "R" with our target variable "W"

# %%
plt.scatter(df["H"],df["W"])

# %% [markdown]
# The data spread of column "H" with our target variable "W"

# %%
plt.scatter(df["3B"],df["W"])

# %% [markdown]
# The data spread of column "3B" with our target variable "W"

# %%
plt.scatter(df["BB"],df["W"])

# %% [markdown]
# The data spread of column "BB" with our target variable "W"

# %%
plt.scatter(df["SB"],df["W"])

# %% [markdown]
# The data spread of column "SB" with our target variable "W"

# %%
plt.scatter(df["RA"],df["W"])

# %% [markdown]
# The data spread of column "RA" with our target variable "W"

# %% [markdown]
# ### DROP THE COLUMNS WITH NEGATIVLY CORRELATED WITH OUR TARGET VARIABLE

# %%
plt.figure(figsize=(15,10))
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# "RA","ER","ERA" columns are negatively correated with our target variable "W" and positively correlated with each other.
#
# "E" is having outliers and shares negative correlation with our target variable "W",hence we will drop it

# %%
df.shape
# Out:
# (30, 17)

# %%
df.drop(["E"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 16)

# %% [markdown]
# Dropped Columns are no longer present in df dataset

# %% [markdown]
# # REMOVING OUTLIERS

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01],
#        [4.83244373e-01, 1.14641931e+00, 2.41521620e-01, 4.01088140e-01,
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df.shape
# Out:
# (30, 16)

# %%
df_new.shape
# Out:
# (29, 16)

# %% [markdown]
# As the rows have been reduced so we can say that the existing outliers has been removed now

# %%
(1/30)
# Out:
# 0.03333333333333333

# %% [markdown]
# So we have lost 0.03% data so far by removing the outliers

# %%
df=df_new
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %% [markdown]
# # SEPARATING THE COLUMNS INTO x AND y

# %%
x=df.drop("W",axis=1)
y=df["W"]

# %%
x.shape
# Out:
# (29, 15)

# %% [markdown]
# We have 29 rows and 13 columns in x

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# we have 29 rows and 1 column in y

# %% [markdown]
# # REMOVING SKEWNESS

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method="yeo-johnson")

# %%
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052224e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800488e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213881e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01],
#        [-1.30829774e+00,  0.00000000e+00,  0.00000000e+00,
# ...

# %% [markdown]
# applied power_transform method to remove the skewness

# %% [markdown]
# # APPLYING SCALING TECHNIQUE

# %%
from sklearn.preprocessing import StandardScaler 
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052224e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800488e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213881e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01],
#        [-1.30829774e+00,  0.00000000e+00,  0.00000000e+00,
# ...

# %% [markdown]
# applied StandardScaler to make all the values in x even

# %% [markdown]
# # APPLYING VARIOUS MODEL

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=3)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %% [markdown]
# ### LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)

lr.score(x_train,y_train)
# Out:
# 0.9393290598666023

# %%
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.9265856471195546

# %% [markdown]
# ### KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
pred_test=knr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.5179015544041452

# %% [markdown]
# ### GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
pred_test=gb.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.8495326288005658

# %% [markdown]
# ### AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
ad=AdaBoostRegressor()
ad.fit(x_train,y_train)
pred_test=ad.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.7614353950777202

# %% [markdown]
# # REGULARIZATION

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import Lasso 


parameters={"alpha":[.0001,.001,.01,.1,1,10],"random_state":list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.9020864644519301

# %% [markdown]
# # CHECKING THE CROSS VALIDATION SCORE

# %% [markdown]
# ### cross_val_score with LinearRegression

# %%
predlr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=r2_score(y_test,predlr)
for j in range(2,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("r2_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- -145.76293586997744
# r2_score is:- 92.65856471195546
#
#
# At cv:- 3
# Cross validation score is:- 43.100686564308084
# r2_score is:- 92.65856471195546
#
#
# At cv:- 4
# Cross validation score is:- 61.62648379484338
# r2_score is:- 92.65856471195546
#
#
# At cv:- 5
# Cross validation score is:- 49.69893310639718
# r2_score is:- 92.65856471195546
#
#
# At cv:- 6
# Cross validation score is:- 37.591509271833104
# r2_score is:- 92.65856471195546
#
#
# At cv:- 7
# Cross validation score is:- 40.28541431466493
# r2_score is:- 92.65856471195546
#
#
# At cv:- 8
# Cross validation score is:- 52.85999739248234
# r2_score is:- 92.65856471195546
#
#
# At cv:- 9
# Cross validation score is:- -227.7301526030497
# r2_score is:- 92.65856471195546

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=4).mean()
print("The cv score is:-",lsscore_selected,"\nThe r2_score is:-",lss)
# Out:
# The cv score is:- 0.6162648379484338
# The r2_score is:- 0.9265856471195546

# %% [markdown]
# ### cross_val_score with KNEIGHBORSREGREESOR

# %%
predknr=knr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=r2_score(y_test,predknr)
for j in range(2,10):
    lsscore=cross_val_score(knr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("r2_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 20.65244587448395
# r2_score is:- 51.79015544041452
#
#
# At cv:- 3
# Cross validation score is:- 16.44649582371027
# r2_score is:- 51.79015544041452
#
#
# At cv:- 4
# Cross validation score is:- 49.405640432302114
# r2_score is:- 51.79015544041452
#
#
# At cv:- 5
# Cross validation score is:- 15.937365963909276
# r2_score is:- 51.79015544041452
#
#
# At cv:- 6
# Cross validation score is:- 17.505002732344323
# r2_score is:- 51.79015544041452
#
#
# At cv:- 7
# Cross validation score is:- 37.24857027961278
# r2_score is:- 51.79015544041452
#
#
# At cv:- 8
# Cross validation score is:- 28.641634847325925
# r2_score is:- 51.79015544041452
#
#
# At cv:- 9
# Cross validation score is:- -1244.0769547744908
# r2_score is:- 51.79015544041452

# %%
lsscore_selected=cross_val_score(knr,x,y,cv=4).mean()
print("The cv score is:-",lsscore_selected,"\nThe r2_score is:-",lss)
# Out:
# The cv score is:- 0.4940564043230211
# The r2_score is:- 0.5179015544041452

# %% [markdown]
# ### cross_val_score with GradientBoostingRegressor

# %%
predgb=gb.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=r2_score(y_test,predgb)
for j in range(2,10):
    lsscore=cross_val_score(gb,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("r2_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- -6.7895253442166625
# r2_score is:- 84.95326288005658
#
#
# At cv:- 3
# Cross validation score is:- -32.01042278874204
# r2_score is:- 84.95326288005658
#
#
# At cv:- 4
# Cross validation score is:- 39.27839805335074
# r2_score is:- 84.95326288005658
#
#
# At cv:- 5
# Cross validation score is:- -112.66393983879226
# r2_score is:- 84.95326288005658
#
#
# At cv:- 6
# Cross validation score is:- -71.8496546677506
# r2_score is:- 84.95326288005658
#
#
# At cv:- 7
# Cross validation score is:- -42.878375107768555
# r2_score is:- 84.95326288005658
#
#
# At cv:- 8
# Cross validation score is:- -76.29168219281934
# r2_score is:- 84.95326288005658
#
#
# At cv:- 9
# Cross validation score is:- -916.3702456549388
# r2_score is:- 84.95326288005658

# %%
lsscore_selected=cross_val_score(gb,x,y,cv=4).mean()
print("The cv score is:-",lsscore_selected,"\nThe r2_score is:-",lss)
# Out:
# The cv score is:- 0.34649186325295034
# The r2_score is:- 0.7614353950777202

# %% [markdown]
# ### cross_val_score with AdaBoostRegressor

# %%
predad=ad.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=r2_score(y_test,predad)
for j in range(2,10):
    lsscore=cross_val_score(ad,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("r2_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- -0.7518021923476226
# r2_score is:- 76.14353950777202
#
#
# At cv:- 3
# Cross validation score is:- -20.877992516707778
# r2_score is:- 76.14353950777202
#
#
# At cv:- 4
# Cross validation score is:- 54.76204528331722
# r2_score is:- 76.14353950777202
#
#
# At cv:- 5
# Cross validation score is:- -76.53163527481738
# r2_score is:- 76.14353950777202
#
#
# At cv:- 6
# Cross validation score is:- -49.257386807060314
# r2_score is:- 76.14353950777202
#
#
# At cv:- 7
# Cross validation score is:- -21.169408337002597
# r2_score is:- 76.14353950777202
#
#
# At cv:- 8
# Cross validation score is:- -2.963432397236776
# r2_score is:- 76.14353950777202
#
#
# At cv:- 9
# Cross validation score is:- -872.1017949464674
# r2_score is:- 76.14353950777202

# %%
lsscore_selected=cross_val_score(ad,x,y,cv=4).mean()
print("The cv score is:-",lsscore_selected,"\nThe r2_score is:-",lss)
# Out:
# The cv score is:- 0.5733144980205825
# The r2_score is:- 0.7614353950777202

# %% [markdown]
# ### cross_val_score with LassoRegressor

# %%
predls=ls.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=r2_score(y_test,predls)
for j in range(2,10):
    lsscore=cross_val_score(ls,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("r2_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 69.41559278737766
# r2_score is:- 90.20864644519301
#
#
# At cv:- 3
# Cross validation score is:- 60.23152043365716
# r2_score is:- 90.20864644519301
#
#
# At cv:- 4
# Cross validation score is:- 70.4867460776247
# r2_score is:- 90.20864644519301
#
#
# At cv:- 5
# Cross validation score is:- 50.76643052357797
# r2_score is:- 90.20864644519301
#
#
# At cv:- 6
# Cross validation score is:- 52.54604788736137
# r2_score is:- 90.20864644519301
#
#
# At cv:- 7
# Cross validation score is:- 41.930721764440236
# r2_score is:- 90.20864644519301
#
#
# At cv:- 8
# Cross validation score is:- 55.48114800208721
# r2_score is:- 90.20864644519301
#
#
# At cv:- 9
# Cross validation score is:- -284.5184836248289
# r2_score is:- 90.20864644519301

# %%
lsscore_selected=cross_val_score(ls,x,y,cv=4).mean()
print("The cv score is:-",lsscore_selected,"\nThe r2_score is:-",lss)
# Out:
# The cv score is:- 0.704867460776247
# The r2_score is:- 0.9020864644519301

# %% [markdown]
# We r getting the best r2_score from lassoRegression model

# %% [markdown]
# # ENSEMBLE TECHNIQUE

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={"criterion":["mse","mae"],"max_features":["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion="mse",max_features="sqrt")

rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_rf=rf.predict(x_test)

rfs=r2_score(y_test,pred_rf)
print('R2_score:',rfs*100)


rfc=(cross_val_score(rf,x,y,cv=4).mean())
print("cross_val_score:",rfc*100)
# Out:
# R2_score: 64.82578691709841
# cross_val_score: 54.067315942794416

# %% [markdown]
# # SAVING THE BEST MODEL

# %%
import joblib
joblib.dump(ls,"base_ls.obj")
# Out:
# ['base_ls.obj']
